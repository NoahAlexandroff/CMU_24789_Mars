# %%
# %cd /content/
# !git clone https://github.com/NoahAlexandroff/CMU_24789_Mars.git 
# !rm -R /content/CMU_24789_Mars/data

# !pip install open3d
# !pip install torchmetrics
import os

# !unzip /content/drive/MyDrive/24-789_Project/data.zip -d /content/CMU_24789_Mars #Make sure your first path aligns with where the data.zip is hosted

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
train_size = 32

# %cd /content/CMU_24789_Mars/
# !python ./unet/train_unet.py --train-size $train_size

new_file = "/content/CMU_24789_Mars/record"+"__trainsize_"+str(train_size)+".pkl"
os.rename("/content/CMU_24789_Mars/record.pkl", new_file)
